# %% [markdown]
# ## compare single method different budget 20 25 30 35

# %%
import json
import numpy as np
import matplotlib.pyplot as plt

fig=plt.figure(num=1,figsize=(21,16))
plt.rc('font', size=14)
ax=fig.add_subplot(3,3,1)
path1 = "/root/autodl-tmp/Matchings_improvement/output/author_approx_20.json"
path2 = "/root/autodl-tmp/Matchings_improvement/output/author_approx_25.json"
path3 = "/root/autodl-tmp/Matchings_improvement/output/author_approx_30.json"
path4 = "/root/autodl-tmp/Matchings_improvement/output/author_approx_35.json"

with open(path1, "r") as f:
    y1 = json.load(f)
with open(path2, "r") as g:
    y2 = json.load(g)

with open(path3, "r") as f:
    y3 = json.load(f)
with open(path4, "r") as g:
    y4 = json.load(g)

y1 = y1["entropy"]
y2 = y2["entropy"]
y3 = y3["entropy"]
y4 = y4["entropy"]

xs = np.arange(11)
ax.set_xlabel("author turns")#添加x轴坐标标签，后面看来没必要会删除它，这里只是为了演示一下。
ax.set_ylabel("uncertainty")
ax.plot(xs, np.array(y1), linestyle='-', marker="o", label="budget=20")
ax.plot(xs, np.array(y2), linestyle='dotted', marker="+", label="budget=25")
ax.plot(xs, np.array(y3), linestyle="dashed", marker="v", label="budget=30")
ax.plot(xs, np.array(y4), linestyle="-", marker="^",label="budget=35")
ax.set_xticks(xs[::2])
ax.legend(loc='upper center') 
   
ax2=fig.add_subplot(3,3,2)
path1 = "/root/autodl-tmp/Matchings_improvement/output/employee_approx_20.json"
path2 = "/root/autodl-tmp/Matchings_improvement/output/employee_approx_25.json"
path3 = "/root/autodl-tmp/Matchings_improvement/output/employee_approx_30.json"
path4 = "/root/autodl-tmp/Matchings_improvement/output/employee_approx_35.json"

with open(path1, "r") as f:
    y1 = json.load(f)
with open(path2, "r") as g:
    y2 = json.load(g)

with open(path3, "r") as f:
    y3 = json.load(f)
with open(path4, "r") as g:
    y4 = json.load(g)

y1 = y1["entropy"]
y2 = y2["entropy"]
y3 = y3["entropy"]
y4 = y4["entropy"]

xs2 = np.arange(11)
ax2.set_xlabel("employee turns")#添加x轴坐标标签，后面看来没必要会删除它，这里只是为了演示一下。
ax2.plot(xs, np.array(y1), linestyle='-', marker="o", label="budget=20")
ax2.plot(xs, np.array(y2), linestyle='dotted', marker="+", label="budget=25")
ax2.plot(xs, np.array(y3), linestyle="dashed", marker="v", label="budget=30")
ax2.plot(xs, np.array(y4), linestyle="-", marker="^",label="budget=35")

ax2.set_xticks(xs2[::2])
ax2.legend(loc='upper center') 

ax3=fig.add_subplot(3,3,3)
path1 = "/root/autodl-tmp/Matchings_improvement/output/purchase_approx_20.json"
path2 = "/root/autodl-tmp/Matchings_improvement/output/purchase_approx_25.json"
path3 = "/root/autodl-tmp/Matchings_improvement/output/purchase_approx_30.json"
path4 = "/root/autodl-tmp/Matchings_improvement/output/purchase_approx_35.json"

with open(path1, "r") as f:
    y1 = json.load(f)
with open(path2, "r") as g:
    y2 = json.load(g)

with open(path3, "r") as f:
    y3 = json.load(f)
with open(path4, "r") as g:
    y4 = json.load(g)

y1 = y1["entropy"]
y2 = y2["entropy"]
y3 = y3["entropy"]
y4 = y4["entropy"]

xs = np.arange(11)
ax3.set_xlabel("purchase turns")#添加x轴坐标标签，后面看来没必要会删除它，这里只是为了演示一下。
ax3.set_ylabel("uncertainty")
ax3.plot(xs, np.array(y1), linestyle='-', marker="o", label="budget=20")
ax3.plot(xs, np.array(y2), linestyle='dotted', marker="+", label="budget=25")
ax3.plot(xs, np.array(y3), linestyle="dashed", marker="v", label="budget=30")
ax3.plot(xs, np.array(y4), linestyle="-", marker="^",label="budget=35")
ax3.set_xticks(xs[::2])
ax3.legend(loc='upper center') 
   

plt.show()

# %%
fig.savefig("./pdf/different-budget.pdf",  dpi=600)

# %% [markdown]
# ## different methods on same budget

# %%
import json
import numpy as np
import matplotlib.pyplot as plt

fig=plt.figure(num=1,figsize=(21,16))
plt.rc('font', size=14)
ax=fig.add_subplot(3,3,1)
path1 = "/root/autodl-tmp/Matchings_improvement/output/author_approx_20.json"
path2 = "/root/autodl-tmp/Matchings_improvement/output/author_brute_20.json"
path3 = "/root/autodl-tmp/Matchings_improvement/output/author_heuristic_20.json"
path4 = "/root/autodl-tmp/Matchings_improvement/output/author_random_20.json"

with open(path1, "r") as f:
    y1 = json.load(f)
with open(path2, "r") as g:
    y2 = json.load(g)

with open(path3, "r") as f:
    y3 = json.load(f)
with open(path4, "r") as g:
    y4 = json.load(g)

y1 = y1["entropy"]
y2 = y2["entropy"]
y3 = y3["entropy"]
y4 = y4["entropy"]

xs = np.arange(11)
ax.set_xlabel("author turns")#添加x轴坐标标签，后面看来没必要会删除它，这里只是为了演示一下。
ax.set_ylabel("uncertainty")
ax.plot(xs, np.array(y1), linestyle='-', marker="o", label="approx")
ax.plot(xs, np.array(y2), linestyle='dotted', marker="+", label="brute")
ax.plot(xs, np.array(y3), linestyle="dashed", marker="v", label="heuristic")
ax.plot(xs, np.array(y4), linestyle="-", marker="^",label="random")
ax.set_xticks(xs[::2])
ax.legend(loc='upper center') 
   
ax2=fig.add_subplot(3,3,2)
path1 = "/root/autodl-tmp/Matchings_improvement/output/employee_approx_20.json"
path2 = "/root/autodl-tmp/Matchings_improvement/output/employee_brute_20.json"
path3 = "/root/autodl-tmp/Matchings_improvement/output/employee_heuristic_20.json"
path4 = "/root/autodl-tmp/Matchings_improvement/output/employee_random_20.json"

with open(path1, "r") as f:
    y1 = json.load(f)
with open(path2, "r") as g:
    y2 = json.load(g)

with open(path3, "r") as f:
    y3 = json.load(f)
with open(path4, "r") as g:
    y4 = json.load(g)

y1 = y1["entropy"]
y2 = y2["entropy"]
y3 = y3["entropy"]
y4 = y4["entropy"]

xs2 = np.arange(11)
ax2.set_xlabel("employee turns")#添加x轴坐标标签，后面看来没必要会删除它，这里只是为了演示一下。
ax2.plot(xs, np.array(y1), linestyle='-', marker="o", label="approx")
ax2.plot(xs, np.array(y2), linestyle='dotted', marker="+", label="brute")
ax2.plot(xs, np.array(y3), linestyle="dashed", marker="v", label="heuristic")
ax2.plot(xs, np.array(y4), linestyle="-", marker="^",label="random")

ax2.set_xticks(xs2[::2])
ax2.legend(loc='upper center') 

ax3=fig.add_subplot(3,3,3)
path1 = "/root/autodl-tmp/Matchings_improvement/output/purchase_approx_20.json"
path2 = "/root/autodl-tmp/Matchings_improvement/output/purchase_brute_20.json"
path3 = "/root/autodl-tmp/Matchings_improvement/output/purchase_heuristic_20.json"
path4 = "/root/autodl-tmp/Matchings_improvement/output/purchase_random_20.json"

with open(path1, "r") as f:
    y1 = json.load(f)
with open(path2, "r") as g:
    y2 = json.load(g)

with open(path3, "r") as f:
    y3 = json.load(f)
with open(path4, "r") as g:
    y4 = json.load(g)

y1 = y1["entropy"]
y2 = y2["entropy"]
y3 = y3["entropy"]
y4 = y4["entropy"]

xs = np.arange(11)
ax3.set_xlabel("purchase turns")#添加x轴坐标标签，后面看来没必要会删除它，这里只是为了演示一下。
ax3.set_ylabel("uncertainty")
ax3.plot(xs, np.array(y1), linestyle='-', marker="o", label="approx")
ax3.plot(xs, np.array(y2), linestyle='dotted', marker="+", label="brute")
ax3.plot(xs, np.array(y3), linestyle="dashed", marker="v", label="heuristic")
ax3.plot(xs, np.array(y4), linestyle="-", marker="^",label="random")
ax3.set_xticks(xs[::2])
ax3.legend(loc='upper center') 
   

plt.show()

# %%
fig.savefig("./pdf/different-methods-compare.pdf-budget=20", dpi=600)

# %% [markdown]
# ## budget 25 compare

# %%
import json
import numpy as np
import matplotlib.pyplot as plt

fig=plt.figure(num=1,figsize=(21,16))
plt.rc('font', size=14)
ax=fig.add_subplot(3,3,1)
path1 = "/root/autodl-tmp/Matchings_improvement/output/author_approx_25.json"
path2 = "/root/autodl-tmp/Matchings_improvement/output/author_brute_25.json"
path3 = "/root/autodl-tmp/Matchings_improvement/output/author_heuristic_25.json"
path4 = "/root/autodl-tmp/Matchings_improvement/output/author_random_25.json"

with open(path1, "r") as f:
    y1 = json.load(f)
with open(path2, "r") as g:
    y2 = json.load(g)

with open(path3, "r") as f:
    y3 = json.load(f)
with open(path4, "r") as g:
    y4 = json.load(g)

y1 = y1["entropy"]
y2 = y2["entropy"]
y3 = y3["entropy"]
y4 = y4["entropy"]

xs = np.arange(11)
ax.set_xlabel("author turns")#添加x轴坐标标签，后面看来没必要会删除它，这里只是为了演示一下。
ax.set_ylabel("uncertainty")
ax.plot(xs, np.array(y1), linestyle='-', marker="o", label="approx")
ax.plot(xs, np.array(y2), linestyle='dotted', marker="+", label="brute")
ax.plot(xs, np.array(y3), linestyle="dashed", marker="v", label="heuristic")
ax.plot(xs, np.array(y4), linestyle="-", marker="^",label="random")
ax.set_xticks(xs[::2])
ax.legend(loc='upper center') 
   
ax2=fig.add_subplot(3,3,2)
path1 = "/root/autodl-tmp/Matchings_improvement/output/employee_approx_25.json"
path2 = "/root/autodl-tmp/Matchings_improvement/output/employee_brute_25.json"
path3 = "/root/autodl-tmp/Matchings_improvement/output/employee_heuristic_25.json"
path4 = "/root/autodl-tmp/Matchings_improvement/output/employee_random_25.json"

with open(path1, "r") as f:
    y1 = json.load(f)
with open(path2, "r") as g:
    y2 = json.load(g)

with open(path3, "r") as f:
    y3 = json.load(f)
with open(path4, "r") as g:
    y4 = json.load(g)

y1 = y1["entropy"]
y2 = y2["entropy"]
y3 = y3["entropy"]
y4 = y4["entropy"]

xs2 = np.arange(11)
ax2.set_xlabel("employee turns")#添加x轴坐标标签，后面看来没必要会删除它，这里只是为了演示一下。
ax2.plot(xs, np.array(y1), linestyle='-', marker="o", label="approx")
ax2.plot(xs, np.array(y2), linestyle='dotted', marker="+", label="brute")
ax2.plot(xs, np.array(y3), linestyle="dashed", marker="v", label="heuristic")
ax2.plot(xs, np.array(y4), linestyle="-", marker="^",label="random")

ax2.set_xticks(xs2[::2])
ax2.legend(loc='upper center') 

ax3=fig.add_subplot(3,3,3)
path1 = "/root/autodl-tmp/Matchings_improvement/output/purchase_approx_25.json"
path2 = "/root/autodl-tmp/Matchings_improvement/output/purchase_brute_25.json"
path3 = "/root/autodl-tmp/Matchings_improvement/output/purchase_heuristic_25.json"
path4 = "/root/autodl-tmp/Matchings_improvement/output/purchase_random_25.json"

with open(path1, "r") as f:
    y1 = json.load(f)
with open(path2, "r") as g:
    y2 = json.load(g)

with open(path3, "r") as f:
    y3 = json.load(f)
with open(path4, "r") as g:
    y4 = json.load(g)

y1 = y1["entropy"]
y2 = y2["entropy"]
y3 = y3["entropy"]
y4 = y4["entropy"]

xs = np.arange(11)
ax3.set_xlabel("purchase turns")#添加x轴坐标标签，后面看来没必要会删除它，这里只是为了演示一下。
ax3.plot(xs, np.array(y1), linestyle='-', marker="o", label="approx")
ax3.plot(xs, np.array(y2), linestyle='dotted', marker="+", label="brute")
ax3.plot(xs, np.array(y3), linestyle="dashed", marker="v", label="heuristic")
ax3.plot(xs, np.array(y4), linestyle="-", marker="^",label="random")
ax3.set_xticks(xs[::2])
ax3.legend(loc='upper center') 

plt.show()

# %%
fig.savefig("./pdf/budget=25-compare.pdf", dpi=600)

# %%
import json
import numpy as np
import matplotlib.pyplot as plt

fig=plt.figure(num=1,figsize=(21,16))
plt.rc('font', size=14)
ax=fig.add_subplot(3,3,1)
path1 = "/root/autodl-tmp/Matchings_improvement/output/author_approx_30.json"
path3 = "/root/autodl-tmp/Matchings_improvement/output/author_heuristic_30.json"
path4 = "/root/autodl-tmp/Matchings_improvement/output/author_random_30.json"

with open(path1, "r") as f:
    y1 = json.load(f)

with open(path3, "r") as f:
    y3 = json.load(f)
with open(path4, "r") as g:
    y4 = json.load(g)

y1 = y1["entropy"]
y3 = y3["entropy"]
y4 = y4["entropy"]

xs = np.arange(11)
ax.set_xlabel("author turns")#添加x轴坐标标签，后面看来没必要会删除它，这里只是为了演示一下。
ax.set_ylabel("uncertainty")
ax.plot(xs, np.array(y1), linestyle='-', marker="o", label="approx")
ax.plot(xs, np.array(y3), linestyle="dashed", marker="v", label="heuristic")
ax.plot(xs, np.array(y4), linestyle="-", marker="^",label="random")
ax.set_xticks(xs[::2])
ax.legend(loc='upper center') 
   
ax2=fig.add_subplot(3,3,2)
path1 = "/root/autodl-tmp/Matchings_improvement/output/employee_approx_30.json"

path3 = "/root/autodl-tmp/Matchings_improvement/output/employee_heuristic_30.json"
path4 = "/root/autodl-tmp/Matchings_improvement/output/employee_random_30.json"

with open(path1, "r") as f:
    y1 = json.load(f)

with open(path3, "r") as f:
    y3 = json.load(f)
with open(path4, "r") as g:
    y4 = json.load(g)

y1 = y1["entropy"]
y3 = y3["entropy"]
y4 = y4["entropy"]

xs2 = np.arange(11)
ax2.set_xlabel("employee turns")#添加x轴坐标标签，后面看来没必要会删除它，这里只是为了演示一下。
ax2.plot(xs, np.array(y1), linestyle='-', marker="o", label="approx")
ax2.plot(xs, np.array(y3), linestyle="dashed", marker="v", label="heuristic")
ax2.plot(xs, np.array(y4), linestyle="-", marker="^",label="random")

ax2.set_xticks(xs2[::2])
ax2.legend(loc='upper center') 

ax3=fig.add_subplot(3,3,3)
path1 = "/root/autodl-tmp/Matchings_improvement/output/purchase_approx_30.json"
path3 = "/root/autodl-tmp/Matchings_improvement/output/purchase_heuristic_30.json"
path4 = "/root/autodl-tmp/Matchings_improvement/output/purchase_random_30.json"

with open(path1, "r") as f:
    y1 = json.load(f)
with open(path3, "r") as f:
    y3 = json.load(f)
with open(path4, "r") as g:
    y4 = json.load(g)

y1 = y1["entropy"]
y3 = y3["entropy"]
y4 = y4["entropy"]

xs = np.arange(11)
ax3.set_xlabel("purchase turns")#添加x轴坐标标签，后面看来没必要会删除它，这里只是为了演示一下。
ax3.plot(xs, np.array(y1), linestyle='-', marker="o", label="approx")
ax3.plot(xs, np.array(y3), linestyle="dashed", marker="v", label="heuristic")
ax3.plot(xs, np.array(y4), linestyle="-", marker="^",label="random")
ax3.set_xticks(xs[::2])
ax3.legend(loc='upper center') 

plt.show()

# %%
fig.savefig("./pdf/budget=30-compare.pdf", dpi=600)

# %%
import json
import numpy as np
import matplotlib.pyplot as plt

fig=plt.figure(num=1,figsize=(21,16))
plt.rc('font', size=14)
ax=fig.add_subplot(3,3,1)
path1 = "/root/autodl-tmp/Matchings_improvement/output/author_approx_35.json"
path3 = "/root/autodl-tmp/Matchings_improvement/output/author_heuristic_35.json"
path4 = "/root/autodl-tmp/Matchings_improvement/output/author_random_35.json"

with open(path1, "r") as f:
    y1 = json.load(f)

with open(path3, "r") as f:
    y3 = json.load(f)
with open(path4, "r") as g:
    y4 = json.load(g)

y1 = y1["entropy"]
y3 = y3["entropy"]
y4 = y4["entropy"]

xs = np.arange(11)
ax.set_xlabel("author turns")#添加x轴坐标标签，后面看来没必要会删除它，这里只是为了演示一下。
ax.set_ylabel("uncertainty")
ax.plot(xs, np.array(y1), linestyle='-', marker="o", label="approx")
ax.plot(xs, np.array(y3), linestyle="dashed", marker="v", label="heuristic")
ax.plot(xs, np.array(y4), linestyle="-", marker="^",label="random")
ax.set_xticks(xs[::2])
ax.legend(loc='upper center') 
   
ax2=fig.add_subplot(3,3,2)
path1 = "/root/autodl-tmp/Matchings_improvement/output/employee_approx_35.json"

path3 = "/root/autodl-tmp/Matchings_improvement/output/employee_heuristic_35.json"
path4 = "/root/autodl-tmp/Matchings_improvement/output/employee_random_35.json"

with open(path1, "r") as f:
    y1 = json.load(f)

with open(path3, "r") as f:
    y3 = json.load(f)
with open(path4, "r") as g:
    y4 = json.load(g)

y1 = y1["entropy"]
y3 = y3["entropy"]
y4 = y4["entropy"]

xs2 = np.arange(11)
ax2.set_xlabel("employee turns")#添加x轴坐标标签，后面看来没必要会删除它，这里只是为了演示一下。
ax2.plot(xs, np.array(y1), linestyle='-', marker="o", label="approx")
ax2.plot(xs, np.array(y3), linestyle="dashed", marker="v", label="heuristic")
ax2.plot(xs, np.array(y4), linestyle="-", marker="^",label="random")

ax2.set_xticks(xs2[::2])
ax2.legend(loc='upper center') 

ax3=fig.add_subplot(3,3,3)
path1 = "/root/autodl-tmp/Matchings_improvement/output/purchase_approx_35.json"
path3 = "/root/autodl-tmp/Matchings_improvement/output/purchase_heuristic_35.json"
path4 = "/root/autodl-tmp/Matchings_improvement/output/purchase_random_35.json"

with open(path1, "r") as f:
    y1 = json.load(f)
with open(path3, "r") as f:
    y3 = json.load(f)
with open(path4, "r") as g:
    y4 = json.load(g)

y1 = y1["entropy"]
y3 = y3["entropy"]
y4 = y4["entropy"]

xs = np.arange(11)
ax3.set_xlabel("purchase turns")#添加x轴坐标标签，后面看来没必要会删除它，这里只是为了演示一下。
ax3.plot(xs, np.array(y1), linestyle='-', marker="o", label="approx")
ax3.plot(xs, np.array(y3), linestyle="dashed", marker="v", label="heuristic")
ax3.plot(xs, np.array(y4), linestyle="-", marker="^",label="random")
ax3.set_xticks(xs[::2])
ax3.legend(loc='upper center') 

plt.show()

# %%
fig.savefig("./pdf/budget=35-compare.pdf", dpi=600)

# %% [markdown]
# ## Time Cost

# %%
import numpy as np
import matplotlib.pyplot as plt
import json

fig=plt.figure(num=1,figsize=(21,16))
plt.rc('font', size=14)

def generate_y(path1):
    with open(path1, "r") as f:
        y1 = sum(json.load(f)["timecost"])
    return y1 

names = ["approx", "heuristic"]
datasets = ["author", "employee", "purchase"]
 
x = []
y = []

for idx, j in enumerate(datasets):
    for i in names:
        base_pth = f"/root/autodl-tmp/Matchings_improvement/output/{j}_{i}_30.json"
        print(j+" "+i+": ")
        print(generate_y(base_pth))
# Out:
# author approx:
# 2.622356653213501
# author heuristic:
# 11.988845348358154
# employee approx:
# 9.264764308929443
# employee heuristic:
# 864.3976736068726
# purchase approx:
# 2.1368467807769775
# purchase heuristic:
# 684.1911761760712

# %%
fig.savefig("./pdf/compare.pdf", dpi=600)

# %% [markdown]
# # precision

# %%
import numpy as np
import matplotlib.pyplot as plt
import json

fig=plt.figure(num=1,figsize=(16,10))
plt.rc('font', size=18)
ax=fig.add_subplot(2,2,1)

y1 = [1.0, 1.0, 0.66, 0.66]
x1 = ["approx", "brute", "heuristic", "random"]

ax.bar(x=x1, height=y1, width=0.4)
ax.set_title("budget=20", fontsize=18)

ax2 = fig.add_subplot(2,2,2)

y2 = [1.0, 1.0, 1.0, 0.66]
x2 = ["approx", "brute", "heuristic", "random"]

ax2.bar(x=x2, height=y2, width=0.4)
ax2.set_title("budget=25", fontsize=18)

ax3 = fig.add_subplot(2,2,3)

y3 = [1.0,  0.66, 1.0]
x3 = ["approx", "heuristic", "random"]

ax3.bar(x=x3, height=y3, width=0.4)
ax3.set_title("budget=30", fontsize=18)

ax4 = fig.add_subplot(2,2,4)

y4 = [1.0, 0.66, 1.0]
x4 = ["approx", "heuristic", "random"]

ax4.bar(x=x4, height=y4, width=0.4)
ax4.set_title("budget=35", fontsize=18)

plt.show()

# %%
fig.savefig("./pdf/precision.pdf", dpi=600)

# %% [markdown]
# ## cost efficiency
